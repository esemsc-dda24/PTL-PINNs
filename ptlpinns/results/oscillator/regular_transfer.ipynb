# %% [markdown]
# ### Load base model (names set as *_nonlinear.pth)

# %%
from ptlpinns.models import model, training, load, transfer
from ptlpinns.odes import forcing, numerical, equations
import numpy as np
import torch
import time
import matplotlib.pyplot as plt

name = "overdamped_nonlinear"
base_path = f"/home/dda24/PTL-PINNs/ptlpinns/models/train/{name}/"
base_name = f"model_{name}.pth"
base_model, training_log = model.load_model(base_path, base_name)
# Out:
# 10 True False False [128, 128, 256]

# %% [markdown]
# ### Initialize transfer learning model

# %%
transfer_model = model.transfer_model(training_log, base_model)

# %% [markdown]
# ### Transfer learning parameters

# %%
w_transfer = [1]
zeta_transfer = [30]
q = 3
N = 512
t_span = (0, 10)
t_eval = np.linspace(t_span[0], t_span[1], N)
ic = [1, 0]
initial_condition_functions = [load.initial_condition(y1_0=ic[0], y2_0=ic[1])]
epsilon = 0.5
equation_functions = [equations.equation_oscillator(w_0=w_transfer[0], epsilon=epsilon, zeta=zeta_transfer[0])]
forcing_functions = [forcing.zeroes_2D(False)]

# %%
ode = equations.ode_oscillator_1D(w_0=w_transfer[0], zeta=zeta_transfer[0], forcing_1D = lambda t: np.zeros_like(t), q=q, epsilon=epsilon)
numerical_solution = numerical.solve_ode_equation(ode, (t_eval[0], t_eval[-1]), t_eval, ic)

# %% [markdown]
# ### Transfer learning

# %%
optimizer = torch.optim.Adam(model.head_parameters(transfer_model), lr=1e-2)
num_iter = 50000
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=300, gamma=0.95)

# %%
transfer.compute_transfer_learning(transfer_model, optimizer, num_iter,
                        equation_functions, initial_condition_functions, forcing_functions,
                        N=N, t_span=t_span, numerical_solution=numerical_solution, every=250,
                        ode_weight=5, ic_weight=1.0)
# Out:
# [iteration] 250 | total 1.024e-01 | ode 1.614e-02 | ic 2.165e-02 | MAE 4.335e-01 | time 8.51
# [iteration] 500 | total 4.472e-01 | ode 8.808e-02 | ic 6.815e-03 | MAE 4.024e-01 | time 19.31
# [iteration] 750 | total 2.552e-02 | ode 4.378e-03 | ic 3.627e-03 | MAE 3.778e-01 | time 27.79
# [iteration] 1000 | total 1.888e-02 | ode 3.372e-03 | ic 2.021e-03 | MAE 3.555e-01 | time 36.35
# [iteration] 1250 | total 1.473e-02 | ode 2.688e-03 | ic 1.295e-03 | MAE 3.337e-01 | time 44.62
# [iteration] 1500 | total 2.587e-02 | ode 4.994e-03 | ic 9.017e-04 | MAE 3.143e-01 | time 52.90
# [iteration] 1750 | total 1.160e-02 | ode 2.165e-03 | ic 7.754e-04 | MAE 2.952e-01 | time 61.03
# [iteration] 2000 | total 9.976e-03 | ode 1.860e-03 | ic 6.743e-04 | MAE 2.763e-01 | time 69.61
# [iteration] 2250 | total 5.233e-02 | ode 1.032e-02 | ic 7.418e-04 | MAE 2.603e-01 | time 78.25
# [iteration] 2500 | total 9.102e-03 | ode 1.706e-03 | ic 5.709e-04 | MAE 2.451e-01 | time 86.36
# [iteration] 2750 | total 7.235e-03 | ode 1.344e-03 | ic 5.131e-04 | MAE 2.300e-01 | time 95.90
# [iteration] 3000 | total 9.130e-01 | ode 1.825e-01 | ic 4.810e-04 | MAE 2.273e-01 | time 103.88
# [iteration] 22750 | total 8.276e-04 | ode 1.048e-04 | ic 3.036e-04 | MAE 3.584e-02 | time 609.04
# [iteration] 23000 | total 8.608e-03 | ode 1.662e-03 | ic 2.952e-04 | MAE 3.745e-02 | time 615.82
# [iteration] 23250 | total 8.192e-04 | ode 1.032e-04 | ic 3.031e-04 | MAE 3.611e-02 | time 622.47
# [iteration] 23500 | total 1.371e-01 | ode 2.736e-02 | ic 2.783e-04 | MAE 4.235e-02 | time 628.99
# [iteration] 23750 | total 8.899e-04 | ode 1.177e-04 | ic 3.014e-04 | MAE 3.573e-02 | time 635.36
# [iteration] 24000 | total 8.015e-04 | ode 9.961e-05 | ic 3.035e-04 | MAE 3.495e-02 | time 642.37
# [iteration] 24250 | total 3.278e-02 | ode 6.488e-03 | ic 3.386e-04 | MAE 4.228e-02 | time 650.23
# [iteration] 24500 | total 1.979e-03 | ode 3.346e-04 | ic 3.057e-04 | MAE 3.648e-02 | time 657.59
# [iteration] 24750 | total 8.275e-04 | ode 1.051e-04 | ic 3.020e-04 | MAE 3.560e-02 | time 666.11
# [iteration] 25000 | total 7.841e-04 | ode 9.619e-05 | ic 3.031e-04 | MAE 3.495e-02 | time 676.66
# [iteration] 25250 | total 3.278e-03 | ode 5.867e-04 | ic 3.445e-04 | MAE 3.874e-02 | time 684.58
# [iteration] 25500 | total 8.372e-04 | ode 1.068e-04 | ic 3.030e-04 | MAE 3.457e-02 | time 690.60
# [iteration] 25750 | total 7.636e-04 | ode 9.216e-05 | ic 3.028e-04 | MAE 3.383e-02 | time 697.24
# [iteration] 26000 | total 1.174e-03 | ode 1.737e-04 | ic 3.056e-04 | MAE 3.308e-02 | time 704.59
# [iteration] 26250 | total 1.889e-02 | ode 3.714e-03 | ic 3.202e-04 | MAE 3.203e-02 | time 712.17
# [iteration] 26500 | total 3.946e-02 | ode 7.835e-03 | ic 2.819e-04 | MAE 3.556e-02 | time 719.23
# [iteration] 26750 | total 7.558e-04 | ode 9.060e-05 | ic 3.028e-04 | MAE 3.327e-02 | time 725.08
# [iteration] 27000 | total 9.338e-04 | ode 1.259e-04 | ic 3.043e-04 | MAE 3.270e-02 | time 731.35
# [iteration] 27250 | total 4.291e-02 | ode 8.523e-03 | ic 2.895e-04 | MAE 3.440e-02 | time 737.45
# [iteration] 27500 | total 1.853e-03 | ode 3.088e-04 | ic 3.094e-04 | MAE 3.429e-02 | time 743.79
# [iteration] 27750 | total 7.294e-04 | ode 8.524e-05 | ic 3.032e-04 | MAE 3.305e-02 | time 750.15
# [iteration] 28000 | total 7.271e-04 | ode 8.477e-05 | ic 3.032e-04 | MAE 3.302e-02 | time 756.19
# [iteration] 28250 | total 7.221e-04 | ode 8.379e-05 | ic 3.031e-04 | MAE 3.281e-02 | time 763.29
# [iteration] 28500 | total 7.182e-04 | ode 8.296e-05 | ic 3.034e-04 | MAE 3.236e-02 | time 772.99
# Converged at iteration 28564: MAE = 0.02482316873265646 | time 775.203931179989

# %% [markdown]
# ### Plotting the results

# %%
plt.plot(t_eval, numerical_solution[0, :], label='Numerical Solution', color='blue')
plt.plot(t_eval, transfer_model(training.generate_eval_tensor(N, t_span, False))[0].squeeze()[:, 0].detach().numpy())
