# %%
import numpy as np
import os
import subprocess
import sys
import json
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# ## Using colab?

# %%
colab = False
token = ""
repo_owner = "esemsc-dda24"
repo_name = "PTL-PINNS"

# %%
if colab:

    def clone_repo(repo_owner: str, repo_name: str, token: str = None):
        """
        Clone a GitHub repo using a token. Token can be passed or taken from GITHUB_TOKEN env var.
        """
        token = token or os.getenv("GITHUB_TOKEN")
        if not token:
            raise ValueError("GitHub token not provided or found in environment variables.")

        url = f"https://{token}@github.com/{repo_owner}/{repo_name}.git"
        target_dir = repo_name

        if not os.path.exists(target_dir):
            try:
                subprocess.run(["git", "clone", url], check=True)
                print(f"Successfully cloned '{repo_name}'.")
            except subprocess.CalledProcessError as e:
                print(f"Error cloning repo: {e}")
        else:
            print(f"Directory '{target_dir}' already exists; skipping git clone.")

    clone_repo(repo_owner, repo_name, token)
    sys.path
    sys.path.append(f"/content/{repo_name}/")
    # !pip install neurodiffeq > /dev/null 2>&1
    # %cd /content/{repo_name}
    # !ls
    # !pip install -e .
    # %cd ..

from ptlpinns.models import load, model, training
from ptlpinns.odes import forcing, equations, numerical
# Out:
# Successfully cloned 'PTL-PINNS'.
# /content/PTL-PINNS
# figures  LICENSE  ptlpinns  pyproject.toml  README.md
# Obtaining file:///content/PTL-PINNS
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from ptlpinns==1.0.0) (3.10.0)
# Requirement already satisfied: neurodiffeq>=0.5.3 in /usr/local/lib/python3.11/dist-packages (from ptlpinns==1.0.0) (0.7.0)
# Requirement already satisfied: numpy>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from ptlpinns==1.0.0) (2.0.2)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.11/dist-packages (from ptlpinns==1.0.0) (1.16.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ptlpinns==1.0.0) (2.6.0+cu124)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from ptlpinns==1.0.0) (4.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->ptlpinns==1.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->ptlpinns==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->ptlpinns==1.0.0) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->ptlpinns==1.0.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->ptlpinns==1.0.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->ptlpinns==1.0.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->ptlpinns==1.0.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->ptlpinns==1.0.0) (2.9.0.post0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from neurodiffeq>=0.5.3->ptlpinns==1.0.0) (0.45.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from neurodiffeq>=0.5.3->ptlpinns==1.0.0) (8.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from neurodiffeq>=0.5.3->ptlpinns==1.0.0) (2.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from neurodiffeq>=0.5.3->ptlpinns==1.0.0) (0.13.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from neurodiffeq>=0.5.3->ptlpinns==1.0.0) (0.3.8)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from neurodiffeq>=0.5.3->ptlpinns==1.0.0) (2.19.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from neurodiffeq>=0.5.3->ptlpinns==1.0.0) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from neurodiffeq>=0.5.3->ptlpinns==1.0.0) (2.32.3)
# Requirement already satisfied: ordered-set in /usr/local/lib/python3.11/dist-packages (from neurodiffeq>=0.5.3->ptlpinns==1.0.0) (4.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->ptlpinns==1.0.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->ptlpinns==1.0.0) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.1->ptlpinns==1.0.0) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->ptlpinns==1.0.0) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (2025.2)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.11/dist-packages (from pytest->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from pytest->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (2.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (2025.8.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (1.74.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (3.8.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->neurodiffeq>=0.5.3->ptlpinns==1.0.0) (3.1.3)
# Building wheels for collected packages: ptlpinns
#   Building editable for ptlpinns (pyproject.toml) ... done
#   Created wheel for ptlpinns: filename=ptlpinns-1.0.0-py3-none-any.whl size=4438 sha256=9355a2db75fb8b4009ce2f08959931e4a31b396391dc6a422655018a1a3acb48
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c8y5tsma/wheels/2b/14/37/f86a63c4ba30a198a2880507af25191d7dbc3607a1fc057f81
# Successfully built ptlpinns
# Installing collected packages: ptlpinns
# Successfully installed ptlpinns-1.0.0
# /content

# %% [markdown]
# ## Training equations

# %%
conf = load.ptl_config("/content/PTL-PINNS/ptlpinns/models/train/config/underdamped.yaml")

# save log
os.makedirs(conf["experiment"], exist_ok = True)
with open(f'{conf["experiment"]}/training_log.json', 'w') as f:
    json.dump(conf, f)

# load values
N = conf["N"]
t_span = (0, conf["t_max"])
t_eval = np.linspace(t_span[0], t_span[1], N)
k, w_list, forcing_freq, forcing_coef = conf["k"], conf["w_list"], conf["forcing_freq"], conf["forcing_coef"]
ic_python_list, zeta_list, mu_list = conf["ic_python_list"], conf["zeta_list"], conf["mu_list"]
ic_list = [load.initial_condition(y1_0=ic[0], y2_0=ic[1]) for ic in ic_python_list]

# %%
# define forcing: sum of cosine functions
forcing_list_numpy = [forcing.underdamped_forcing(True, forcing_freq[i], forcing_coef[i], mu_list[i], zeta_list[i]) for i in range(k)]

forcing_list_torch = [forcing.underdamped_forcing(False, forcing_freq[i], forcing_coef[i], mu_list[i], zeta_list[i]) for i in range(k)]

# %%
# returns 2D linear equation functions
linear_equation_functions_np = [equations.ode_oscillator(forcing_list_numpy[k],
                                                    w_0=w_list[k],
                                                    epsilon=0, zeta=zeta_list[k], numpy=True)
                                                    for k in range(k)]

# solves the 2D linear equation functions
title_list = [rf"ic = {ic_python_list[i]}, $\Omega \in {forcing_freq[i]}$, $\mu = {mu_list[i]}$"
              for i in range(k)]


linear_solution_list = [numerical.solve_ode_equation(linear_equation_functions_np[index], t_span, t_eval, ic_python_list[index]) for index in range(k)]

# visualize the solutions of the training equations
numerical.plot_multiple_ode_solutions(linear_solution_list,
                                       t_eval, titles=title_list,
                                       suptitle=r"$\ddot{x} + 2 \zeta \omega_0 \dot{x} + w^2_0 x = \sum \gamma_k e^{- \mu \zeta t} \cos(\Omega_k \sqrt{1 - \zeta^2})$", hspace = 1.2)

# %% [markdown]
# ## Model Configuration

# %%
use_sine, use_fourier, n_frequencies, scale, bias = conf["use_sine"], conf["use_fourier"], conf["n_frequencies"], conf["scale"], conf["bias"]
hidden_layers, num_iter, learning_rate = conf["hidden_layers"], conf["num_iter"], conf["lr"]
step_size, gamma, method = conf["step_size"], conf["gamma"], conf["method"]
ode_weight, ic_weight = conf["w_ode"], conf["w_ic"]


# define model
pinn = model.Multihead_model_fourier(k, use_sine=use_sine, use_fourier=use_fourier, n_frequencies=n_frequencies,
                                      scale=scale, bias=bias, HIDDEN_LAYERS=hidden_layers)

dev = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pinn.to(dev)
# Out:
# Multihead_model_fourier(
#   (fourier): FourierFeatures()
#   (linear1): SineLayer(
#     (linear): Linear(in_features=32, out_features=128, bias=True)
#   )
#   (linear2): SineLayer(
#     (linear): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (linear3): Linear(in_features=128, out_features=256, bias=True)
#   (final_layers): ModuleList(
#     (0-11): 12 x Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
x0_harmonic = np.cos(np.sqrt(1 - zeta_list[1] ** 2) * t_eval) + (zeta_list[1] / (1 - zeta_list[1] ** 2)) * np.sin(np.sqrt(1 - zeta_list[1] ** 2) * t_eval)

plt.plot(t_eval, linear_solution_list[1][0, :], label='linear solution')
plt.plot(t_eval, np.exp(- zeta_list[1] * t_eval) * x0_harmonic, label='analytical')
plt.legend()

# %%
every=100
save_epoch=100
optimizer=torch.optim.Adam(pinn.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %% [markdown]
# ## Train Neural Network on Linear version

# %%
equation_functions = []
for i in range(k):
    equation_functions.append(equations.equation_oscillator(w_0=w_list[i], epsilon=0, zeta=zeta_list[i]))

# %%
loss_trace, ode_trace, ic_trace, result_trace = training.train(model=pinn, optimizer=optimizer, num_iter=num_iter, equation_functions=equation_functions,
                                                      initial_condition_functions=ic_list, forcing_functions=forcing_list_torch,
                                                      N=N, t_span=t_span, every=every, save_epoch=save_epoch, ode_weight=ode_weight,
                                                      ic_weight=ic_weight, scheduler=scheduler, method=method)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 100th Iter: total 0.14764755974351068, ode 0.14727533647438634, ic 0.0003722232691243492
# 200th Iter: total 0.03511840504970416, ode 0.03487439005123634, ic 0.00024401499846782304
# 300th Iter: total 0.015607167277385195, ode 0.015491257823036791, ic 0.00011590945434840382
# 400th Iter: total 0.009265353205735245, ode 0.009223378496371375, ic 4.1974709363870285e-05
# 500th Iter: total 0.005316304502969884, ode 0.005245824280551956, ic 7.048022241792689e-05
# 600th Iter: total 0.0034235647419598217, ode 0.003336609985321699, ic 8.695475663812242e-05
# 700th Iter: total 0.001929546250274961, ode 0.0019236637444302901, ic 5.882505844670891e-06
# 800th Iter: total 0.0033774463858433695, ode 0.003197682490270486, ic 0.00017976389557288375
# 900th Iter: total 0.0010963881755931386, ode 0.0010949225384875342, ic 1.465637105604363e-06
# 1000th Iter: total 0.0017743702553669526, ode 0.0016732540112654307, ic 0.00010111624410152174
# 1100th Iter: total 0.0007236598130674576, ode 0.0007231682590540376, ic 4.915540134200015e-07
# 1200th Iter: total 0.0006177212206430142, ode 0.0006142047833713144, ic 3.516437271699784e-06
# 1300th Iter: total 0.0005147890508012121, ode 0.0005137659414472994, ic 1.0231093539127256e-06
# 1400th Iter: total 0.0004318483734998934, ode 0.0004307363909445135, ic 1.111982555379927e-06
# 1500th Iter: total 0.0003648777397660605, ode 0.0003644788744724889, ic 3.9886529357162923e-07
# 1600th Iter: total 0.000313770377164916, ode 0.00031353575272666825, ic 2.3462443824775555e-07
# 1700th Iter: total 0.0003165194702909136, ode 0.00030803233536466504, ic 8.487134926248565e-06
# 1800th Iter: total 0.0006814217837483839, ode 0.0005478451022197997, ic 0.00013357668152858416
# 1900th Iter: total 0.00019753689253221432, ode 0.00019652770675466092, ic 1.0091857775534026e-06
# 2000th Iter: total 0.0001672795683222284, ode 0.00016674983243865045, ic 5.297358835779563e-07
# 2100th Iter: total 0.0001859090418553373, ode 0.00018429297773075805, ic 1.6160641245792517e-06
# 2200th Iter: total 0.0010867042671940104, ode 0.0006723187576697903, ic 0.00041438550952422015
# 2300th Iter: total 0.00016631310726447515, ode 0.00016555723091249693, ic 7.558763519782191e-07
# 2400th Iter: total 0.00010069196419103915, ode 9.851798259664192e-05, ic 2.173981594397226e-06
# 2500th Iter: total 8.962822120116106e-05, ode 8.918144295674247e-05, ic 4.467782444185881e-07
# 2600th Iter: total 0.00018558561877222825, ode 0.00017911562915649926, ic 6.469989615728994e-06
# 2700th Iter: total 0.0002273295632505059, ode 0.00021248164454056872, ic 1.4847918709937192e-05
# 2800th Iter: total 0.00016281751700249837, ode 0.00015563608834106782, ic 7.181428661430558e-06
# 2900th Iter: total 0.0006315388997002417, ode 0.0004420419118250008, ic 0.00018949698787524088
# 3000th Iter: total 7.707947405580629e-05, ode 7.165775317196338e-05, ic 5.421720883842911e-06
# 3100th Iter: total 0.00012544748413259777, ode 9.73046534752853e-05, ic 2.814283065731248e-05
# 3200th Iter: total 6.158203778795878e-05, ode 6.106395591287358e-05, ic 5.180818750852005e-07
# 3300th Iter: total 0.0006177965387731469, ode 0.0004326882742196952, ic 0.00018510826455345167
# 3400th Iter: total 5.8280713678752994e-05, ode 5.586499627460278e-05, ic 2.415717404150214e-06
# 3500th Iter: total 4.6629529762606935e-05, ode 4.644526975368693e-05, ic 1.842600089200022e-07
# 3600th Iter: total 0.0012271264262606963, ode 0.0009629497996426547, ic 0.00026417662661804166
# 3700th Iter: total 0.00026593254551959513, ode 0.0002611350039535593, ic 4.797541566035825e-06
# 3800th Iter: total 0.0003422253977763915, ode 0.0002922826342422624, ic 4.99427635341291e-05
# 3900th Iter: total 4.8194213285297504e-05, ode 4.3927418993822535e-05, ic 4.266794291474969e-06
# 4000th Iter: total 4.062412149876263e-05, ode 3.738485512146972e-05, ic 3.2392663772929124e-06
# 4100th Iter: total 3.1534565776970026e-05, ode 3.054659533086787e-05, ic 9.879704461021533e-07
# 4200th Iter: total 0.000902012363683217, ode 0.0008600490267988315, ic 4.196333688438552e-05
# 4300th Iter: total 0.00026221969120455627, ode 0.00025393023424684667, ic 8.289456957709591e-06
# 4400th Iter: total 3.787732790073406e-05, ode 3.613067509801205e-05, ic 1.7466528027220147e-06
# 4500th Iter: total 5.0667215087525645e-05, ode 4.857011703220782e-05, ic 2.097098055317821e-06
# 4600th Iter: total 2.387799852557326e-05, ode 2.376429294360835e-05, ic 1.13705581964907e-07
# 4700th Iter: total 9.335029086256777e-05, ode 7.831783386068023e-05, ic 1.503245700188754e-05
# 4800th Iter: total 4.00339190370546e-05, ode 3.836633844401013e-05, ic 1.6675805930444778e-06
# 4900th Iter: total 0.0006301779946989563, ode 0.0005203610518708127, ic 0.00010981694282814365
# 5000th Iter: total 5.6646774150726365e-05, ode 5.0358119464494715e-05, ic 6.288654686231647e-06
# 5100th Iter: total 3.0244674056740007e-05, ode 2.856773919664861e-05, ic 1.6769348600913976e-06
# 5200th Iter: total 0.0004437526411213066, ode 0.00024317337399489648, ic 0.0002005792671264101
# 5300th Iter: total 4.252719100370699e-05, ode 4.0020188287249114e-05, ic 2.5070027164578814e-06
# 5400th Iter: total 2.671245480346156e-05, ode 2.6373707541168693e-05, ic 3.38747262292864e-07
# 5500th Iter: total 5.5394093221041826e-05, ode 5.0357745201354453e-05, ic 5.0363480196873725e-06
# 5600th Iter: total 1.741675845103916e-05, ode 1.73316744426594e-05, ic 8.508400837976198e-08
# 5700th Iter: total 0.00014827900558280654, ode 0.00011028628525839015, ic 3.799272032441639e-05
# 5800th Iter: total 0.000213709917010023, ode 0.00017254486664137111, ic 4.116505036865189e-05
# 5900th Iter: total 2.0781659633884393e-05, ode 2.0589538705345454e-05, ic 1.9212092853893756e-07
# 6000th Iter: total 0.00022060473900123494, ode 0.00020593780095381635, ic 1.4666938047418584e-05
# 6100th Iter: total 1.463965069973655e-05, ode 1.4628306369279362e-05, ic 1.1344330457188678e-08
# 6200th Iter: total 8.984585694988253e-05, ode 7.714280698039623e-05, ic 1.2703049969486297e-05
# 6300th Iter: total 4.23272623805847e-05, ode 3.755318928994123e-05, ic 4.774073090643469e-06
# 6400th Iter: total 2.289694491238022e-05, ode 2.2445600064866658e-05, ic 4.5134484751356245e-07
# 6500th Iter: total 5.63446054346585e-05, ode 5.318190297877727e-05, ic 3.1627024558812234e-06
# 6600th Iter: total 1.2910316048181973e-05, ode 1.289718821017171e-05, ic 1.3127838010263602e-08
# 6700th Iter: total 0.0002594161521590145, ode 0.00021956814748032294, ic 3.984800467869153e-05
# 6800th Iter: total 7.706724384837896e-05, ode 6.518939481099256e-05, ic 1.1877849037386405e-05
# 6900th Iter: total 8.187650213511097e-05, ode 6.0087159690872514e-05, ic 2.178934244423846e-05
# 7000th Iter: total 0.00010458273429374396, ode 0.00010125998226529696, ic 3.32275202844699e-06
# 7100th Iter: total 1.575709385808804e-05, ode 1.480650032941504e-05, ic 9.50593528673001e-07
# 7200th Iter: total 5.099104607969553e-05, ode 4.091343923376215e-05, ic 1.007760684593338e-05
# 7300th Iter: total 0.00014097504870797724, ode 0.00013152436669168488, ic 9.450682016292357e-06
# 7400th Iter: total 2.1855808031621e-05, ode 2.0437901282041066e-05, ic 1.4179067495799336e-06
# 7500th Iter: total 5.064349770429463e-05, ode 4.758955577557356e-05, ic 3.0539419287210696e-06
# 7600th Iter: total 1.0300880599910092e-05, ode 1.0298578997903422e-05, ic 2.301602006671667e-09
# 7700th Iter: total 5.578576448861469e-05, ode 4.054296584638725e-05, ic 1.5242798642227442e-05
# 7800th Iter: total 6.664218833017883e-05, ode 6.129632019313156e-05, ic 5.34586813704727e-06
# 7900th Iter: total 1.2216423640254878e-05, ode 1.1502901455607127e-05, ic 7.135221846477512e-07
# 8000th Iter: total 2.7091561861033636e-05, ode 2.5160730269289e-05, ic 1.9308315917446374e-06
# 8100th Iter: total 9.28335335087305e-06, ode 9.282697891356186e-06, ic 6.554595168649959e-10
# 8200th Iter: total 4.807939468707127e-05, ode 3.29857139910784e-05, ic 1.509368069599287e-05
# 8300th Iter: total 4.308606336032407e-05, ode 3.4617100608657904e-05, ic 8.46896275166616e-06
# 8400th Iter: total 3.795382607352065e-05, ode 3.3761124886022765e-05, ic 4.1927011874978875e-06
# 8500th Iter: total 2.1855927504875376e-05, ode 1.9842946944329117e-05, ic 2.012980560546259e-06
# 8600th Iter: total 8.510411310687122e-06, ode 8.50922254047235e-06, ic 1.1887702147720078e-09
# 8700th Iter: total 6.81906823509797e-05, ode 5.100264511738849e-05, ic 1.7188037233591212e-05
# 8800th Iter: total 1.758953185451633e-05, ode 1.7405197001019217e-05, ic 1.8433485349711494e-07
# 8900th Iter: total 6.795336268508008e-05, ode 5.3970335477413264e-05, ic 1.3983027207666819e-05
# 9000th Iter: total 3.7205195810945455e-05, ode 3.500399973116149e-05, ic 2.2011960797839646e-06
# 9100th Iter: total 8.168131522463329e-06, ode 8.149462423471848e-06, ic 1.866909899148092e-08
# 9200th Iter: total 6.200556542526892e-05, ode 5.3859272883921745e-05, ic 8.146292541347171e-06
# 9300th Iter: total 1.6811487382514788e-05, ode 1.571207692870245e-05, ic 1.0994104538123382e-06
# 9400th Iter: total 6.368675020790608e-05, ode 5.135826057663743e-05, ic 1.2328489631268657e-05
# 9500th Iter: total 4.200240960876001e-05, ode 2.8470978566585677e-05, ic 1.3531431042174335e-05
# 9600th Iter: total 7.732137431000304e-06, ode 7.722252898575328e-06, ic 9.884532424976658e-09
# 9700th Iter: total 8.482793804474228e-05, ode 5.547611456791925e-05, ic 2.935182347682304e-05
# 9800th Iter: total 4.218546300369069e-05, ode 3.50040376531173e-05, ic 7.1814253505733916e-06
# 9900th Iter: total 1.6812361674044278e-05, ode 1.5712557739367347e-05, ic 1.0998039346769298e-06
# 10000th Iter: total 7.75613923147305e-05, ode 6.396810933192641e-05, ic 1.3593282982804087e-05

# %% [markdown]
# ### View results and save

# %%
training.plot_loss(loss_trace, ode_trace, ic_trace, path=None)

# %%
# compute the NN solutions
pinn.eval()
pinn.to('cpu')
NN_solution, _ = pinn(training.generate_eval_tensor(N=N, t_span=t_span, require_grad=False))
NN_solution = NN_solution.detach().numpy()

name = conf["experiment"]
torch.save(pinn.state_dict(), f"/content/PTL-PINNS/ptlpinns/models/train/{name}/model_{name}.pth")

# %%
training.compare_training_solutions(NN_solution, linear_solution_list, t_eval, title_list, k)
